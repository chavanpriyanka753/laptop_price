# %%
# !python --version
# Out:
# Python 3.8.10

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Lenovo\Desktop\python_batch\new_project\laptop_data.csv")
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(["Unnamed: 0"], axis = 1, inplace = True)

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                     Cpu  Ram     Memory                           Gpu  OpSys  \
# 0  Intel Core i5 2.3GHz  8GB  128GB SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight       Price
# 0  1.37kg  71378.6832

# %%
df.duplicated().sum()
# Out:
# 29

# %%
df = df.drop_duplicates(ignore_index = True)
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1269    Asus            Notebook    15.6
# 1270  Lenovo  2 in 1 Convertible    14.0
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1272  Lenovo            Notebook    14.0
# 1273      HP            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1269                                    1366x768
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1274 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   object
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   object
#  10  Price             1274 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 109.6+ KB

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df['Ram'] = df['Ram'].astype('int')
df['Weight'] = df['Weight'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1274 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int32
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float64
#  10  Price             1274 non-null   float64
# dtypes: float64(3), int32(1), object(7)
# memory usage: 104.6+ KB

# %%
df['Price'] = df['Price'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1274 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int32
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float64
#  10  Price             1274 non-null   int32
# dtypes: float64(2), int32(2), object(7)
# memory usage: 99.7+ KB

# %%
import seaborn as sns

# %%
sns.displot(df['Price'], kind = "kde", fill = True)

# %%
df['Company'].value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x = df['Company'], y = df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = df['TypeName'], y = df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
sns.displot(df['Inches'], kind = 'kde')

# %%
sns.scatterplot(x = df['Inches'], y = df['Price'])
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                505
# 1366x768                                         262
# IPS Panel Full HD 1920x1080                      226
# IPS Panel Full HD / Touchscreen 1920x1080         51
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# ...

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
df.sample(3)
# Out:
#      Company  TypeName  Inches                  ScreenResolution  \
# 440   Lenovo  Notebook    17.3                          1600x900
# 1110      HP  Notebook    13.3  Quad HD+ / Touchscreen 3200x1800
# 1167  Lenovo  Notebook    15.6                 Full HD 1920x1080
#
#                             Cpu  Ram     Memory                    Gpu  \
# 440   AMD A6-Series 9220 2.5GHz    8    1TB HDD          AMD Radeon R4
# 1110   Intel Core M 6Y54 1.1GHz    8  256GB SSD  Intel HD Graphics 515
# 1167   Intel Core i3 6006U 2GHz    4    1TB HDD  Nvidia GeForce 920MX
#
#            OpSys  Weight  Price  Touchscreen
# 440   Windows 10    2.80  27652            0
# 1110  Windows 10    1.16  90522            1
# 1167  Windows 10    2.20  24935            0

# %%
df['HD'] = df['ScreenResolution'].apply(lambda x: 1 if 'HD' in x else 0)

# %%
df.sample(3)
# Out:
#     Company            TypeName  Inches  \
# 212      HP            Notebook    15.6
# 876    Asus            Notebook    15.6
# 95     Acer  2 in 1 Convertible    13.3
#
#                               ScreenResolution  \
# 212                          Full HD 1920x1080
# 876                                   1366x768
# 95   IPS Panel Full HD / Touchscreen 1920x1080
#
#                                       Cpu  Ram     Memory  \
# 212              Intel Core i3 6006U 2GHz    4  500GB HDD
# 876  Intel Pentium Quad Core N4200 1.1GHz    4    1TB HDD
# 95             Intel Core i5 8250U 1.6GHz    8  256GB SSD
#
#                         Gpu       OpSys  Weight  Price  Touchscreen  HD
# 212   Intel HD Graphics 520       No OS     2.1  18594            0   1
# 876   Intel HD Graphics 505       Linux     2.0  21258            0   0
# 95   Intel UHD Graphics 620  Windows 10     1.5  45128            1   1

# %%
df['Touchscreen'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = df['Touchscreen'], y = df['Price'])
# Out:
# <AxesSubplot:xlabel='Touchscreen', ylabel='Price'>

# %%
df['IPS'] = df['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
df.sample(3)
# Out:
#      Company            TypeName  Inches  \
# 993   Lenovo            Notebook    15.6
# 112   Lenovo  2 in 1 Convertible    13.3
# 1038    Dell            Notebook    15.6
#
#                                ScreenResolution                         Cpu  \
# 993                           Full HD 1920x1080  Intel Core i5 6200U 2.3GHz
# 112   IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i5 7200U 2.5GHz
# 1038                          Full HD 1920x1080  Intel Core i5 6300U 2.4GHz
#
#       Ram     Memory                    Gpu       OpSys  Weight  Price  \
# 993     8  256GB SSD  Intel HD Graphics 520  Windows 10    2.30  71874
# 112     8  256GB SSD  Intel HD Graphics 620  Windows 10    1.37  74538
# 1038    8  256GB SSD  Intel HD Graphics 520   Windows 7    2.09  56633
#
#       Touchscreen  HD  IPS
# 993             0   1    0
# 112             1   1    1
# 1038            0   1    0

# %%
df['IPS'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = df['IPS'], y = df['Price'])
# Out:
# <AxesSubplot:xlabel='IPS', ylabel='Price'>

# %%
new = df['ScreenResolution'].str.split('x', expand = True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight   Price  Touchscreen  HD  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378            0   0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895            0   0    0
# ...

# %%
df['X_res'] = df['X_res'].str.findall(r'\d+\.?\d+').apply(lambda x: x[0])
df['X_res']
# Out:
# 0       2560
# 1       1440
# 2       1920
# 3       2880
# 4       2560
#         ...
# 1269    1366
# 1270    1920
# 1271    3200
# 1272    1366
# 1273    1366
# Name: X_res, Length: 1274, dtype: object

# %%
df['X_res'].isna().sum()
# Out:
# 0

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res']=  df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1274 entries, 0 to 1273
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int32
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float64
#  10  Price             1274 non-null   int32
#  11  Touchscreen       1274 non-null   int64
#  12  HD                1274 non-null   int64
#  13  IPS               1274 non-null   int64
#  14  X_res             1274 non-null   int32
#  15  Y_res             1274 non-null   int32
# ...

# %%
df.corr()['Price']
# Out:
# Inches         0.066990
# Ram            0.740106
# Weight         0.212192
# Price          1.000000
# Touchscreen    0.188630
# HD             0.367844
# IPS            0.250357
# X_res          0.552074
# Y_res          0.548111
# Name: Price, dtype: float64

# %%
df['ppi'] = (((df['X_res']**2 + df['Y_res']**2 )**0.5 )/ df['Inches']).astype('float')

# %%
df.corr()['Price']
# Out:
# Inches         0.066990
# Ram            0.740106
# Weight         0.212192
# Price          1.000000
# Touchscreen    0.188630
# HD             0.367844
# IPS            0.250357
# X_res          0.552074
# Y_res          0.548111
# ppi            0.469538
# Name: Price, dtype: float64

# %%
df.drop(['ScreenResolution', 'Inches', 'X_res', 'Y_res'], axis = 1, inplace = True)

# %%
df.head(1)
# Out:
#   Company   TypeName                   Cpu  Ram     Memory  \
# 0   Apple  Ultrabook  Intel Core i5 2.3GHz    8  128GB SSD
#
#                             Gpu  OpSys  Weight  Price  Touchscreen  HD  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378            0   0    1
#
#           ppi
# 0  226.983005

# %%
df.rename({'IPS': 'Ips'}, axis = 1)
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1269    Asus            Notebook            Intel Core i7 6500U 2.5GHz    4
# 1270  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1271  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1272  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1273      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
#
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz     190
# Intel Core i7 7700HQ 2.8GHz    146
# Intel Core i7 7500U 2.7GHz     132
# Intel Core i7 8550U 1.8GHz      73
# Intel Core i5 8250U 1.6GHz      72
#                               ...
# Intel Core M M3-6Y30 0.9GHz      1
# AMD A9-Series 9420 2.9GHz        1
# Intel Core i5 2.9GHz             1
# AMD A6-Series 7310 2GHz          1
# AMD A9-Series 9410 2.9GHz        1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
df['Cpu Name']
# Out:
# 0            Intel Core i5
# 1            Intel Core i5
# 2            Intel Core i5
# 3            Intel Core i7
# 4            Intel Core i5
#                ...
# 1269         Intel Core i7
# 1270         Intel Core i7
# 1271         Intel Core i7
# 1272    Intel Celeron Dual
# 1273         Intel Core i7
# Name: Cpu Name, Length: 1274, dtype: object

# %%
df.sample(3)
# Out:
#      Company  TypeName                         Cpu  Ram     Memory  \
# 1027      HP  Notebook  Intel Core i5 7200U 2.5GHz    4  500GB HDD
# 262       HP  Notebook  Intel Core i5 8250U 1.6GHz    4  500GB HDD
# 1043  Lenovo  Notebook  Intel Core i5 6200U 2.3GHz    8  256GB SSD
#
#                         Gpu       OpSys  Weight  Price  Touchscreen  HD  IPS  \
# 1027  Intel HD Graphics 620  Windows 10    1.95  56476            0   0    0
# 262   Intel HD Graphics 620  Windows 10    2.10  38468            0   1    1
# 1043  Intel HD Graphics 520  Windows 10    2.30  55922            0   1    0
#
#              ppi       Cpu Name
# 1027  111.935204  Intel Core i5
# 262   141.211998  Intel Core i5
# 1043  141.211998  Intel Core i5

# %%
df['Cpu Name'].value_counts()
# Out:
# Intel Core i7               515
# Intel Core i5               423
# Intel Core i3               134
# Intel Celeron Dual           69
# Intel Pentium Quad           27
# Intel Core M                 17
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# Intel Celeron Quad            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# Intel Atom X5-Z8350           2
# Intel Xeon E3-1535M           2
# AMD A9-Series A9-9420         2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A10-Series 9600P          2
# AMD A6-Series A6-9220         2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# AMD A10-Series A10-9620P      2
# Intel Atom x5-Z8300           1
# AMD E-Series 9000             1
# Samsung Cortex A72&A53        1
# AMD FX 8800P                  1
# ...

# %%
df['Cpu Name'].apply(lambda x: x.split()[0]).value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df[df['Cpu Name'] == 'Samsung Cortex A72&A53']
# Out:
#       Company            TypeName                            Cpu  Ram  \
# 1191  Samsung  2 in 1 Convertible  Samsung Cortex A72&A53 2.0GHz    4
#
#                   Memory                Gpu      OpSys  Weight  Price  \
# 1191  32GB Flash Storage  ARM Mali T860 MP4  Chrome OS    1.15  35111
#
#       Touchscreen  HD  IPS       ppi                Cpu Name
# 1191            1   0    1  234.5074  Samsung Cortex A72&A53

# %%
df = df[(df['Cpu Name'] != 'Samsung Cortex A72&A53')]

# %%
df
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1269    Asus            Notebook            Intel Core i7 6500U 2.5GHz    4
# 1270  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1271  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1272  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1273      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
#
# ...

# %%
df.reset_index(drop = True, inplace = True)

# %%
df
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1268    Asus            Notebook            Intel Core i7 6500U 2.5GHz    4
# 1269  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1270  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1271  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1272      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
#
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i3' or text == 'Intel Core i5' or text == 'Intel Core i7':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu Brand'] = df['Cpu Name'].apply(fetch_processor)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5436\329281503.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu Brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.sample(3)
# Out:
#     Company  TypeName                          Cpu  Ram                Memory  \
# 224    Dell    Gaming  Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 288  Lenovo    Gaming  Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 725  Lenovo  Notebook   Intel Core i5 7200U 2.5GHz    4               1TB HDD
#
#                             Gpu       OpSys  Weight   Price  Touchscreen  HD  \
# 224     Nvidia GeForce GTX 1060  Windows 10    4.42  130873            0   1
# 288  Nvidia GeForce GTX 1050 Ti  Windows 10    2.50   62817            0   1
# 725       Intel HD Graphics 620       No OS    1.90   26101            0   0
#
#      IPS         ppi       Cpu Name      Cpu Brand
# 224    1  127.335675  Intel Core i7  Intel Core i7
# 288    1  141.211998  Intel Core i7  Intel Core i7
# 725    0  100.454670  Intel Core i5  Intel Core i5

# %%
df['Cpu Brand'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = df['Cpu Brand'], y = df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.drop(['Cpu', 'Cpu Name'], axis =1, inplace =True)

# %%
df.sample(3)
# Out:
#      Company  TypeName  Ram                Memory                      Gpu  \
# 939     Dell    Gaming   16  512GB SSD +  1TB HDD  Nvidia GeForce GTX 1080
# 1122      HP  Notebook    8             256GB SSD    Intel HD Graphics 520
# 1199    Dell  Notebook    4             128GB SSD       AMD Radeon R7 M440
#
#            OpSys  Weight   Price  Touchscreen  HD  IPS         ppi  \
# 939   Windows 10    4.36  146946            0   0    0  169.780899
# 1122   Windows 7    1.43   80612            0   1    0  157.350512
# 1199  Windows 10    2.30   26586            0   0    0  100.454670
#
#           Cpu Brand
# 939   Intel Core i7
# 1122  Intel Core i5
# 1199  Intel Core i3

# %%
df['Ram'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = df['Ram'], y = df['Price'])
# Out:
# <AxesSubplot:xlabel='Ram', ylabel='Price'>

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          215
# 500GB HDD                        123
# 512GB SSD                        114
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                35
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 64GB Flash Storage                13
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 1.0TB Hybrid                       7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory'] = df['Memory'].str.replace('\.0','')
df['Memory'] = df['Memory'].str.replace('GB','')
df['Memory'] = df['Memory'].str.replace('TB','000')
new = df['Memory'].str.split('+', expand = True)
new
# Out:
#                       0     1
# 0               128 SSD  None
# 1     128 Flash Storage  None
# 2               256 SSD  None
# 3               512 SSD  None
# 4               256 SSD  None
# ...                 ...   ...
# 1268            500 HDD  None
# 1269            128 SSD  None
# 1270            512 SSD  None
# 1271   64 Flash Storage  None
# 1272           1000 HDD  None
#
# [1273 rows x 2 columns]

# %%
new[0].value_counts()
# Out:
# 256 SSD              412
# 1000 HDD             216
# 500 HDD              123
# 512 SSD              114
# 128 SSD               96
# 256 SSD               88
# 128 SSD               74
# 32 Flash Storage      35
# 512 SSD               20
# 2000 HDD              16
# 1000 SSD              14
# 64 Flash Storage      13
# 256 Flash Storage      8
# 16 Flash Storage       7
# 1000 Hybrid            7
# 32 SSD                 6
# 180 SSD                5
# 128 Flash Storage      4
# 16 SSD                 3
# 1000 SSD               2
# 512 Flash Storage      2
# 64 SSD                 1
# 64 Flash Storage       1
# 1000 HDD               1
# 32 HDD                 1
# 128 HDD                1
# 240 SSD                1
# 8 SSD                  1
# 508 Hybrid             1
# Name: 0, dtype: int64

# %%
new[1].value_counts()
# Out:
#   1000 HDD       185
#   2000 HDD        15
#   256 SSD          3
#   500 HDD          2
#   1000 Hybrid      2
#   512 SSD          1
# Name: 1, dtype: int64

# %%
df['First'] = new[0]
df['First'] = df['First'].str.strip()

df['Second'] = new[1]

# %%
df['Layer1HDD'] = df['First'].apply(lambda x: 1 if 'HDD' in x else 0)
df['Layer1SSD'] = df['First'].apply(lambda x: 1 if 'SSD' in x else 0)
df['Layer1Hybrid'] = df['First'].apply(lambda x: 1 if 'Hybrid' in x else 0)
df['Layer1Flash_Storage'] = df['First'].apply(lambda x: 1 if 'Flash Storage' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight   Price  Touchscreen  HD  IPS         ppi      Cpu Brand  \
# 0  macOS    1.37   71378            0   0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895            0   0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636            0   1    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195            0   0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095            0   0    1  226.983005  Intel Core i5
#
#                First Second  Layer1HDD  Layer1SSD  Layer1Hybrid  \
# ...

# %%
df['First'] = df['First'].str.replace(r'\D', '')
df['Second'] = df['Second'].fillna('0')
df['Second'].isna().sum()
# Out:
# 0

# %%
df['Layer2HDD'] = df['Second'].apply(lambda x: 1 if 'HDD' in x else 0)
df['Layer2SSD'] = df['Second'].apply(lambda x: 1 if 'SSD' in x else 0)
df['Layer2Hybrid'] = df['Second'].apply(lambda x: 1 if 'Hybrid' in x else 0)
df['Layer2Flash_Storage'] = df['Second'].apply(lambda x: 1 if 'Flash Storage' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight   Price  Touchscreen  HD  ...  First  Second Layer1HDD  \
# 0  macOS    1.37   71378            0   0  ...    128       0         0
# 1  macOS    1.34   47895            0   0  ...    128       0         0
# 2  No OS    1.86   30636            0   1  ...    256       0         0
# 3  macOS    1.83  135195            0   0  ...    512       0         0
# 4  macOS    1.37   96095            0   0  ...    256       0         0
#
#   Layer1SSD Layer1Hybrid  Layer1Flash_Storage  Layer2HDD  Layer2SSD  \
# ...

# %%
df['Second'] = df['Second'].str.replace(r'\D', '')

# %%
df
# Out:
#      Company            TypeName  Ram             Memory  \
# 0      Apple           Ultrabook    8            128 SSD
# 1      Apple           Ultrabook    8  128 Flash Storage
# 2         HP            Notebook    8            256 SSD
# 3      Apple           Ultrabook   16            512 SSD
# 4      Apple           Ultrabook    8            256 SSD
# ...      ...                 ...  ...                ...
# 1268    Asus            Notebook    4            500 HDD
# 1269  Lenovo  2 in 1 Convertible    4            128 SSD
# 1270  Lenovo  2 in 1 Convertible   16            512 SSD
# 1271  Lenovo            Notebook    2   64 Flash Storage
# 1272      HP            Notebook    6           1000 HDD
#
#                                Gpu       OpSys  Weight   Price  Touchscreen  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378            0
# 1           Intel HD Graphics 6000       macOS    1.34   47895            0
# ...

# %%
df['First'] = df['First'].astype('int')
df['Second'] = df['Second'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1273 entries, 0 to 1272
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company              1273 non-null   object
#  1   TypeName             1273 non-null   object
#  2   Ram                  1273 non-null   int32
#  3   Memory               1273 non-null   object
#  4   Gpu                  1273 non-null   object
#  5   OpSys                1273 non-null   object
#  6   Weight               1273 non-null   float64
#  7   Price                1273 non-null   int32
#  8   Touchscreen          1273 non-null   int64
#  9   HD                   1273 non-null   int64
#  10  IPS                  1273 non-null   int64
#  11  ppi                  1273 non-null   float64
#  12  Cpu Brand            1273 non-null   object
#  13  First                1273 non-null   int32
#  14  Second               1273 non-null   int32
# ...

# %%
df['HDD'] = df['First'] * df['Layer1HDD'] + df['Second'] * df['Layer2HDD']
df['SSD'] = df['First'] * df['Layer1SSD'] + df['Second'] * df['Layer2SSD']
df['Hybrid'] = df['First'] * df['Layer1Hybrid'] + df['Second'] * df['Layer2Hybrid']
df['Flash_Storage'] = df['First'] * df['Layer1Flash_Storage'] + df['Second'] * df['Layer2Flash_Storage']

# %%
df.drop(['First', 'Second', 'Layer1HDD', 'Layer2HDD', 'Layer1SSD', 'Layer2SSD', 'Layer1Hybrid', 
         'Layer2Hybrid', 'Layer1Flash_Storage', 'Layer2Flash_Storage'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight   Price  Touchscreen  HD  IPS         ppi      Cpu Brand  \
# 0  macOS    1.37   71378            0   0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895            0   0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636            0   1    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195            0   0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095            0   0    1  226.983005  Intel Core i5
#
#    HDD  SSD  Hybrid  Flash_Storage
# ...

# %%
df['Flash_Storage'].value_counts()
# Out:
# 0      1203
# 32       35
# 64       14
# 256       8
# 16        7
# 128       4
# 512       2
# Name: Flash_Storage, dtype: int64

# %%
df['Hybrid'].value_counts()
# Out:
# 0       1263
# 1000       9
# 508        1
# Name: Hybrid, dtype: int64

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram   Memory                           Gpu  OpSys  \
# 0   Apple  Ultrabook    8  128 SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight  Price  Touchscreen  HD  IPS         ppi      Cpu Brand  HDD  SSD  \
# 0    1.37  71378            0   0    1  226.983005  Intel Core i5    0  128
#
#    Hybrid  Flash_Storage
# 0       0              0

# %%
df.drop(['Memory'], axis = 1, inplace = True)

# %%
df.corr()['Price']
# Out:
# Ram              0.739996
# Weight           0.211667
# Price            1.000000
# Touchscreen      0.190382
# HD               0.367427
# IPS              0.251514
# ppi              0.471481
# HDD             -0.098481
# SSD              0.669808
# Hybrid           0.022490
# Flash_Storage   -0.036712
# Name: Price, dtype: float64

# %%
df.drop(['Hybrid', 'Flash_Storage'], axis = 1, inplace = True)

# %%
df
# Out:
#      Company            TypeName  Ram                           Gpu  \
# 0      Apple           Ultrabook    8  Intel Iris Plus Graphics 640
# 1      Apple           Ultrabook    8        Intel HD Graphics 6000
# 2         HP            Notebook    8         Intel HD Graphics 620
# 3      Apple           Ultrabook   16            AMD Radeon Pro 455
# 4      Apple           Ultrabook    8  Intel Iris Plus Graphics 650
# ...      ...                 ...  ...                           ...
# 1268    Asus            Notebook    4           Nvidia GeForce 920M
# 1269  Lenovo  2 in 1 Convertible    4         Intel HD Graphics 520
# 1270  Lenovo  2 in 1 Convertible   16         Intel HD Graphics 520
# 1271  Lenovo            Notebook    2             Intel HD Graphics
# 1272      HP            Notebook    6            AMD Radeon R5 M330
#
#            OpSys  Weight   Price  Touchscreen  HD  IPS         ppi  \
# 0          macOS    1.37   71378            0   0    1  226.983005
# ...

# %%
# Gpu = graphical processing unit
# Ppi = pixel per inches

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      279
# Intel HD Graphics 520      181
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Intel Graphics 620           1
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# Nvidia GeForce 960M          1
# Name: Gpu, Length: 109, dtype: int64

# %%
df['Gpu Brand'] = df['Gpu'].apply(lambda x: x.split()[0])
df['Gpu Brand']
# Out:
# 0        Intel
# 1        Intel
# 2        Intel
# 3          AMD
# 4        Intel
#          ...
# 1268    Nvidia
# 1269     Intel
# 1270     Intel
# 1271     Intel
# 1272       AMD
# Name: Gpu Brand, Length: 1273, dtype: object

# %%
df['Gpu Brand'].value_counts()
# Out:
# Intel     703
# Nvidia    396
# AMD       174
# Name: Gpu Brand, dtype: int64

# %%
df['Gpu Brand'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = df['Gpu Brand'], y = df['Price'])
# Out:
# <AxesSubplot:xlabel='Gpu Brand', ylabel='Price'>

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  Price  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37  71378
#
#    Touchscreen  HD  IPS         ppi      Cpu Brand  HDD  SSD Gpu Brand
# 0            0   0    1  226.983005  Intel Core i5    0  128     Intel

# %%
df.drop(['Gpu'], axis = 1, inplace = True )

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight   Price  Touchscreen  HD  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378            0   0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895            0   0    0
# 2      HP   Notebook    8  No OS    1.86   30636            0   1    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195            0   0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095            0   0    1
#
#           ppi      Cpu Brand  HDD  SSD Gpu Brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1047
# No OS             66
# Linux             58
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x = df['OpSys'], y = df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['Os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight   Price  Touchscreen  HD  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378            0   0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895            0   0    0
# 2      HP   Notebook    8  No OS    1.86   30636            0   1    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195            0   0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095            0   0    1
#
#           ppi      Cpu Brand  HDD  SSD Gpu Brand                  Os
# 0  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df.drop(['OpSys'], axis = 1, inplace = True)

# %%
sns.barplot(x = df['Os'], y = df['Price'])
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram  Weight  Price  Touchscreen  HD  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37  71378            0   0    1  226.983005
#
#        Cpu Brand  HDD  SSD Gpu Brand   Os
# 0  Intel Core i5    0  128     Intel  Mac

# %%
sns.displot(df['Weight'], kind = 'kde')

# %%
sns.scatterplot(x = df['Weight'], y = df['Price'])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Price'>

# %%
df.corr()['Price']
# Out:
# Ram            0.739996
# Weight         0.211667
# Price          1.000000
# Touchscreen    0.190382
# HD             0.367427
# IPS            0.251514
# ppi            0.471481
# HDD           -0.098481
# SSD            0.669808
# Name: Price, dtype: float64

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.displot(df['Price'], kind = 'kde')

# %%
sns.displot(np.log(df['Price']), kind = 'kde')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1273 entries, 0 to 1272
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1273 non-null   object
#  1   TypeName     1273 non-null   object
#  2   Ram          1273 non-null   int32
#  3   Weight       1273 non-null   float64
#  4   Price        1273 non-null   int32
#  5   Touchscreen  1273 non-null   int64
#  6   HD           1273 non-null   int64
#  7   IPS          1273 non-null   int64
#  8   ppi          1273 non-null   float64
#  9   Cpu Brand    1273 non-null   object
#  10  HDD          1273 non-null   int64
#  11  SSD          1273 non-null   int64
#  12  Gpu Brand    1273 non-null   object
#  13  Os           1273 non-null   object
# dtypes: float64(2), int32(2), int64(5), object(5)
# memory usage: 129.4+ KB

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight   Price  Touchscreen  HD  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378            0   0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895            0   0    0  127.677940
# 2      HP   Notebook    8    1.86   30636            0   1    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195            0   0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095            0   0    1  226.983005
#
#        Cpu Brand  HDD  SSD Gpu Brand                  Os
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
df['Company'].value_counts().to_dict()
# Out:
# {'Dell': 291,
#  'Lenovo': 289,
#  'HP': 268,
#  'Asus': 151,
#  'Acer': 101,
#  'MSI': 54,
#  'Toshiba': 48,
#  'Apple': 21,
#  'Samsung': 8,
#  'Razer': 7,
#  'Mediacom': 7,
#  'Microsoft': 6,
#  'Xiaomi': 4,
#  'Vero': 4,
#  'Chuwi': 3,
#  'Google': 3,
#  'Fujitsu': 3,
#  'LG': 3,
#  'Huawei': 2}

# %%
df['Company'] = df['Company'].replace({'Dell': 0,
 'Lenovo': 1,
 'HP': 2,
 'Asus': 3,
 'Acer': 4,
 'MSI': 5,
 'Toshiba': 6,
 'Apple': 7,
 'Samsung': 8,
 'Razer': 9,
 'Mediacom': 10,
 'Microsoft': 11,
 'Xiaomi': 12,
 'Vero': 13,
 'Chuwi': 14,
 'Google': 15,
 'Fujitsu': 16,
 'LG': 17,
 'Huawei': 18})

# %%
df.head(1)
# Out:
#    Company   TypeName  Ram  Weight  Price  Touchscreen  HD  IPS         ppi  \
# 0        7  Ultrabook    8    1.37  71378            0   0    1  226.983005
#
#        Cpu Brand  HDD  SSD Gpu Brand   Os
# 0  Intel Core i5    0  128     Intel  Mac

# %%
df['TypeName'].value_counts().to_dict()
# Out:
# {'Notebook': 706,
#  'Gaming': 205,
#  'Ultrabook': 194,
#  '2 in 1 Convertible': 116,
#  'Workstation': 29,
#  'Netbook': 23}

# %%
df['TypeName'] = df['TypeName'].replace({'Notebook': 0,
 'Gaming': 1,
 'Ultrabook': 2,
 '2 in 1 Convertible': 3,
 'Workstation': 4,
 'Netbook': 5})

# %%
df.head(1)
# Out:
#    Company  TypeName  Ram  Weight  Price  Touchscreen  HD  IPS         ppi  \
# 0        7         2    8    1.37  71378            0   0    1  226.983005
#
#        Cpu Brand  HDD  SSD Gpu Brand   Os
# 0  Intel Core i5    0  128     Intel  Mac

# %%
df['Cpu Brand'].value_counts().to_dict()
# Out:
# {'Intel Core i7': 515,
#  'Intel Core i5': 423,
#  'Other Intel Processor': 141,
#  'Intel Core i3': 134,
#  'AMD Processor': 60}

# %%
df['Cpu Brand'] = df['Cpu Brand'].replace({'Intel Core i7': 0,
 'Intel Core i5': 1,
 'Other Intel Processor': 2,
 'Intel Core i3': 3,
 'AMD Processor': 4})

# %%
df.head(1)
# Out:
#    Company  TypeName  Ram  Weight  Price  Touchscreen  HD  IPS         ppi  \
# 0        7         2    8    1.37  71378            0   0    1  226.983005
#
#    Cpu Brand  HDD  SSD Gpu Brand   Os
# 0          1    0  128     Intel  Mac

# %%
df['Gpu Brand'].value_counts().to_dict()
# Out:
# {'Intel': 703, 'Nvidia': 396, 'AMD': 174}

# %%
df['Gpu Brand'] = df['Gpu Brand'].replace({'Intel': 0, 'Nvidia': 1, 'AMD': 2})

# %%
df.head(1)
# Out:
#    Company  TypeName  Ram  Weight  Price  Touchscreen  HD  IPS         ppi  \
# 0        7         2    8    1.37  71378            0   0    1  226.983005
#
#    Cpu Brand  HDD  SSD  Gpu Brand   Os
# 0          1    0  128          0  Mac

# %%
df['Os'].value_counts().to_dict()
# Out:
# {'Windows': 1100, 'Others/No OS/Linux': 152, 'Mac': 21}

# %%
df['Os'] = df['Os'].replace({'Windows': 0, 'Mac': 1, 'Others/No OS/Linux': 2})

# %%
df.head(1)
# Out:
#    Company  TypeName  Ram  Weight  Price  Touchscreen  HD  IPS         ppi  \
# 0        7         2    8    1.37  71378            0   0    1  226.983005
#
#    Cpu Brand  HDD  SSD  Gpu Brand  Os
# 0          1    0  128          0   1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1273 entries, 0 to 1272
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1273 non-null   int64
#  1   TypeName     1273 non-null   int64
#  2   Ram          1273 non-null   int32
#  3   Weight       1273 non-null   float64
#  4   Price        1273 non-null   int32
#  5   Touchscreen  1273 non-null   int64
#  6   HD           1273 non-null   int64
#  7   IPS          1273 non-null   int64
#  8   ppi          1273 non-null   float64
#  9   Cpu Brand    1273 non-null   int64
#  10  HDD          1273 non-null   int64
#  11  SSD          1273 non-null   int64
#  12  Gpu Brand    1273 non-null   int64
#  13  Os           1273 non-null   int64
# dtypes: float64(2), int32(2), int64(10)
# memory usage: 129.4 KB

# %%
x = df.drop(['Price'], axis = 1)
y = df['Price']

# %%
x
# Out:
#       Company  TypeName  Ram  Weight  Touchscreen  HD  IPS         ppi  \
# 0           7         2    8    1.37            0   0    1  226.983005
# 1           7         2    8    1.34            0   0    0  127.677940
# 2           2         0    8    1.86            0   1    0  141.211998
# 3           7         2   16    1.83            0   0    1  220.534624
# 4           7         2    8    1.37            0   0    1  226.983005
# ...       ...       ...  ...     ...          ...  ..  ...         ...
# 1268        3         0    4    2.20            0   0    0  100.454670
# 1269        1         3    4    1.80            1   1    1  157.350512
# 1270        1         3   16    1.30            1   1    1  276.053530
# 1271        1         0    2    1.50            0   0    0  111.935204
# 1272        2         0    6    2.19            0   0    0  100.454670
#
#       Cpu Brand   HDD  SSD  Gpu Brand  Os
# 0             1     0  128          0   1
# ...

# %%
y
# Out:
# 0        71378
# 1        47895
# 2        30636
# 3       135195
# 4        96095
#          ...
# 1268     38378
# 1269     33992
# 1270     79866
# 1271     12201
# 1272     40705
# Name: Price, Length: 1273, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.15, random_state = 2)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((1082, 13), (191, 13), (1082,), (191,))

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import r2_score, mean_absolute_error

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# model evaluation on training data

y_pred = model.predict(x_train)
r2 = r2_score(y_pred, y_train)
mae = mean_absolute_error(y_pred, y_train)
print(f'r2 for training data = {r2}')
print(f'mae for training data = {mae}')
# Out:
# r2 for training data = 0.6488173133535764
# mae for training data = 13891.677690558312

# %%
# model evaluation on testing data

y_pred = model.predict(x_test)
r2 = r2_score(y_pred, y_test)
mae = mean_absolute_error(y_pred, y_test)
print(f'r2 for testing data = {r2}')
print(f'mae for testing data = {mae}')
# Out:
# r2 for testing data = 0.5610594892106875
# mae for testing data = 14098.69693267115

# %%
np.exp(0.19)
# Out:
# 1.2092495976572515

# %%
import pickle

with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)
